# %% [markdown]
# ### Importing Libaries

# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt # visulization purpose

# %%
import warnings                   # to avoid the warnings
warnings.filterwarnings('ignore')

# %%
x=[10,20,40]
y=[20,60,80]

# %%
fig = plt.figure(figsize=(10,8))

plt.plot(x,y)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Line Graph',size=15)
plt.suptitle('Sales comparision',size=10)
# Out:
# Text(0.5, 0.98, 'Sales comparision')

# %%
fig=plt.subplots(nrows=1,ncols=1) # bydefault we have 1 row and 1 column

# %%
fig=plt.subplots(nrows=3,ncols=1)

# %%
fig=plt.subplots(nrows=3,ncols=4) 
plt.xlabel('Sale')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# ### Data visualization in dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'C:\Users\Admin\Downloads\mtcars.csv')

# %%
df=pd.read_csv(r'C:/Users/Admin/Downloads/mtcars.csv')

# %%
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
df.size
# Out:
# 352

# %%
df.shape
# Out:
# (32, 11)

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df[['gear']]
# Out:
#     gear
# 0      4
# 1      4
# 2      4
# 3      3
# 4      3
# 5      3
# 6      3
# 7      4
# 8      4
# 9      4
# 10     4
# 11     3
# 12     3
# 13     3
# 14     3
# 15     3
# 16     3
# 17     4
# 18     4
# 19     4
# 20     3
# 21     3
# 22     3
# 23     3
# 24     3
# 25     4
# 26     5
# 27     5
# 28     5
# 29     5
# 30     5
# 31     4

# %%
df[['gear']].value_counts()
# Out:
# gear
# 3       15
# 4       12
# 5        5
# dtype: int64

# %%
df[['gear']].value_counts()
df.gear.value_counts().plot()
# Out:
# <Axes: >

# %%
df.gear.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='gear'>

# %%
df[['cyl']].value_counts()
# Out:
# cyl
# 8      14
# 4      11
# 6       7
# dtype: int64

# %%
df.cyl.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='cyl'>

# %%
df.cyl.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# Histogram
plt.hist(df['mpg'],bins=8,color='pink')
# Out:
# (array([3., 7., 7., 6., 3., 2., 2., 2.]),
#  array([10.4   , 13.3375, 16.275 , 19.2125, 22.15  , 25.0875, 28.025 ,
#         30.9625, 33.9   ]),
#  <BarContainer object of 8 artists>)

# %%
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
# scatter plot : need to required 2 variable
plt.scatter(df.mpg,df.wt)

# %%
plt.scatter(df.mpg,df.qsec)

# %%
# box plot

# %%
plt.boxplot(df['mpg'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c6f06db940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c6f06dbe80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c6f06db6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c6f0620130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c6f08ba5c0>],
#  'means': []}

# %%
plt.boxplot(df['mpg'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c6f0787760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c6f08d8fd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c6f08d8910>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c6f08d9510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c6f08d97b0>],
#  'means': []}

# %%
plt.boxplot(df['mpg'],vert=False)
plt.xlabel('MPG'),plt.ylabel('MPG1'),plt.title('Box Plot')
# Out:
# (Text(0.5, 0, 'MPG'), Text(0, 0.5, 'MPG1'), Text(0.5, 1.0, 'Box Plot'))

# %%
plt.violinplot(df['mpg'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1c6f1c5e5f0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1c6f1c5e560>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1c6f1c5e590>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1c6f1c5eef0>}

# %% [markdown]
# ### Seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# sns library is used to load the data

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Univariate : one variable

# %%
sns.stripplot(df)   #strip plot is used when we have data is in numerical format
# Out:
# <Axes: >

# %%
sns.stripplot(df['size'])
# Out:
# <Axes: ylabel='size'>

# %%
sns.stripplot(y='tip',data=df)
# Out:
# <Axes: ylabel='tip'>
