# %% [markdown]
# # Support Vector Machine

# %% [markdown]
# Supervided ML Algorithm mostly used for classification but often used for regression.
# - __SVM is used for linearly seperable and non linear(circular boundary)__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - SVM is used to train with boundary line in which items as critical to differentiate the exceptional cases
# - __draw a margin in shuch a way that 2 classes are equidistance from boundary__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Optimization Problem__
# - draw 2 margines and then take the average mid line in between
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - gamma
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
